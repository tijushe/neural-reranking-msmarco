# %% [markdown]
# # Training

# %% [markdown]
# ## Installation

# %%
# !pip install sentence-transformers==3.4.1
# Out:
# Collecting sentence-transformers==3.4.1
#   Downloading sentence_transformers-3.4.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==3.4.1) (4.51.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==3.4.1) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==3.4.1) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==3.4.1) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==3.4.1) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==3.4.1) (0.31.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==3.4.1) (11.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers==3.4.1) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers==3.4.1) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers==3.4.1) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers==3.4.1) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers==3.4.1) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers==3.4.1) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==3.4.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==3.4.1) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==3.4.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==3.4.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==3.4.1) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==3.4.1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==3.4.1) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==3.4.1) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==3.4.1) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==3.4.1) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==3.4.1) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==3.4.1) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==3.4.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==3.4.1) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==3.4.1) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==3.4.1) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==3.4.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers==3.4.1) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers==3.4.1) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers==3.4.1) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers==3.4.1) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers==3.4.1) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers==3.4.1) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers==3.4.1) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers==3.4.1) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers==3.4.1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers==3.4.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers==3.4.1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers==3.4.1) (2025.4.26)
# Downloading sentence_transformers-3.4.1-py3-none-any.whl (275 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.9/275.9 kB 19.6 MB/s eta 0:00:00
# Installing collected packages: sentence-transformers
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 4.0.0
#     Uninstalling sentence-transformers-4.0.0:
#       Successfully uninstalled sentence-transformers-4.0.0
# Successfully installed sentence-transformers-3.4.1

# %%
# !pip install pytrec_eval
# Out:
# Requirement already satisfied: pytrec_eval in /usr/local/lib/python3.11/dist-packages (0.5)

# %% [markdown]
# ## Imports

# %%
"""
This examples show how to train a Cross-Encoder for the MS Marco dataset (https://github.com/microsoft/MSMARCO-Passage-Ranking).

The query and the passage are passed simoultanously to a Transformer network. The network then returns
a score between 0 and 1 how relevant the passage is for a given query.

The resulting Cross-Encoder can then be used for passage re-ranking: You retrieve for example 100 passages
for a given query, for example with ElasticSearch, and pass the query+retrieved_passage to the CrossEncoder
for scoring. You sort the results then according to the output of the CrossEncoder.

This gives a significant boost compared to out-of-the-box ElasticSearch / BM25 ranking.
"""
from torch.utils.data import DataLoader
from sentence_transformers import LoggingHandler, util
from sentence_transformers.cross_encoder import CrossEncoder
from sentence_transformers.cross_encoder.evaluation import CERerankingEvaluator
from sentence_transformers import InputExample
from datetime import datetime
import gzip
import os
import tarfile
import tqdm
import logging
from collections import defaultdict
import numpy as np
import sys
import pytrec_eval
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
logging.basicConfig(format='%(asctime)s - %(message)s',datefmt='%Y-%m-%d %H:%M:%S')

# %% [markdown]
# ## Training preparation

# %% [markdown]
# ### Initialize hyperparameters (e.g., batch size, etc)

# %% [markdown]
# #### To prevent from losing the trained model because of getting disconnected from google colab, we suggest you to store trained model on your google drive. In below we do that by loading google.colab and set the path.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
base_path = "./gdrive/MyDrive/cross-encoder-reranker-ir-course-2023/"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !mkdir -p $base_path

# %%
#First, we define the transformer model we want to fine-tune

train_batch_size = 32
num_epochs = 1
# We train the network with as a binary label task
# Given [query, passage] is the label 0 = irrelevant or 1 = relevant?
# We use a positive-to-negative ratio: For 1 positive sample (label 1) we include 4 negative samples (label 0)
# in our training setup. For the negative samples, we use the triplets provided by MS Marco that
# specify (query, positive sample, negative sample).
pos_neg_ration = 4

# Maximal number of training samples we want to use
max_train_samples = 5e6 #2e7

# %% [markdown]
# ## Load model (cross-encoder/ms-marco-MiniLM-L-2-v2)

# %%
#We set num_labels=1, which predicts a continous score between 0 and 1
model_name = 'cross-encoder/ms-marco-MiniLM-L-2-v2'
# model_name = 'cross-encoder/ms-marco-TinyBERT-L-2-v2'
# model_name = 'distilroberta-base'
model = CrossEncoder(model_name, num_labels=1, max_length=512)
model_save_path = base_path  +'finetuned_models/cross-encoder-'+model_name.replace("/", "-")+'-'+datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /cross-encoder/ms-marco-MiniLM-L-2-v2/resolve/main/config.json HTTP/1.1" 307 0
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /cross-encoder/ms-marco-MiniLM-L2-v2/resolve/main/config.json HTTP/1.1" 200 0
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /cross-encoder/ms-marco-MiniLM-L-2-v2/resolve/main/tokenizer_config.json HTTP/1.1" 307 0
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /cross-encoder/ms-marco-MiniLM-L2-v2/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# INFO:sentence_transformers.cross_encoder.CrossEncoder:Use pytorch device: cuda

# %% [markdown]
# ## Download MSMARCO data + BM25 initial ranking run file

# %%
# !wget https://msmarco.z22.web.core.windows.net/msmarcoranking/queries.tar.gz
# !tar -xvzf  queries.tar.gz
# Out:
# --2025-05-16 11:01:18--  https://msmarco.z22.web.core.windows.net/msmarcoranking/queries.tar.gz
# Resolving msmarco.z22.web.core.windows.net (msmarco.z22.web.core.windows.net)... 20.150.34.1
# Connecting to msmarco.z22.web.core.windows.net (msmarco.z22.web.core.windows.net)|20.150.34.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18882551 (18M) [application/gzip]
# Saving to: ‘queries.tar.gz.5’
#
# queries.tar.gz.5    100%[===================>]  18.01M  4.92MB/s    in 3.8s
#
# 2025-05-16 11:01:23 (4.70 MB/s) - ‘queries.tar.gz.5’ saved [18882551/18882551]
#
# queries.dev.tsv
# queries.eval.tsv
# queries.train.tsv

# %%
### Now we read the MS Marco dataset
data_folder = 'msmarco-data'
os.makedirs(data_folder, exist_ok=True)


#### Read the corpus files, that contain all the passages. Store them in the corpus dict
corpus = {}
collection_filepath = os.path.join(data_folder, 'collection.tsv')
if not os.path.exists(collection_filepath):
    tar_filepath = os.path.join(data_folder, 'collection.tar.gz')
    if not os.path.exists(tar_filepath):
        logging.info("Download collection.tar.gz")
        util.http_get('https://msmarco.z22.web.core.windows.net/msmarcoranking/collection.tar.gz', tar_filepath)

    with tarfile.open(tar_filepath, "r:gz") as tar:
        tar.extractall(path=data_folder)

with open(collection_filepath, 'r', encoding='utf8') as fIn:
    for line in fIn:
        pid, passage = line.strip().split("\t")
        corpus[pid] = passage


### Read the train queries, store in queries dict
queries = {}
queries_filepath = os.path.join('queries.train.tsv')
with open(queries_filepath, 'r', encoding='utf8') as fIn:
    for line in fIn:
        qid, query = line.strip().split("\t")
        queries[qid] = query



### Now we create our training & dev data
train_samples = []
dev_samples = {}

# We use 200 random queries from the train set for evaluation during training
# Each query has at least one relevant and up to 200 irrelevant (negative) passages
num_dev_queries = 200
num_max_dev_negatives = 200

# msmarco-qidpidtriples.rnd-shuf.train-eval.tsv.gz and msmarco-qidpidtriples.rnd-shuf.train.tsv.gz is a randomly
# shuffled version of qidpidtriples.train.full.2.tsv.gz from the MS Marco website
# We extracted in the train-eval split 500 random queries that can be used for evaluation during training
train_eval_filepath = os.path.join(data_folder, 'msmarco-qidpidtriples.rnd-shuf.train-eval.tsv.gz')
if not os.path.exists(train_eval_filepath):
    logging.info("Download "+os.path.basename(train_eval_filepath))
    util.http_get('https://sbert.net/datasets/msmarco-qidpidtriples.rnd-shuf.train-eval.tsv.gz', train_eval_filepath)

with gzip.open(train_eval_filepath, 'rt') as fIn:
    for line in fIn:
        qid, pos_id, neg_id = line.strip().split()

        if qid not in dev_samples and len(dev_samples) < num_dev_queries:
            dev_samples[qid] = {'query': queries[qid], 'positive': set(), 'negative': set()}

        if qid in dev_samples:
            dev_samples[qid]['positive'].add(corpus[pos_id])

            if len(dev_samples[qid]['negative']) < num_max_dev_negatives:
                dev_samples[qid]['negative'].add(corpus[neg_id])


# Read our training file
train_filepath = os.path.join(data_folder, 'msmarco-qidpidtriples.rnd-shuf.train.tsv.gz')
if not os.path.exists(train_filepath):
    logging.info("Download "+os.path.basename(train_filepath))
    util.http_get('https://sbert.net/datasets/msmarco-qidpidtriples.rnd-shuf.train.tsv.gz', train_filepath)

cnt = 0
with gzip.open(train_filepath, 'rt') as fIn:
    for line in tqdm.tqdm(fIn, unit_scale=True):
        qid, pos_id, neg_id = line.strip().split()

        if qid in dev_samples:
            continue

        query = queries[qid]
        if (cnt % (pos_neg_ration+1)) == 0:
            passage = corpus[pos_id]
            label = 1
        else:
            passage = corpus[neg_id]
            label = 0

        train_samples.append(InputExample(texts=[query, passage], label=label))
        cnt += 1

        if cnt >= max_train_samples:
            break
# Out:
# 5.00Mit [00:37, 135kit/s]

# %% [markdown]
# ## Initialize dataloader

# %%
# We create a DataLoader to load our train samples
train_dataloader = DataLoader(train_samples, shuffle=True, batch_size=train_batch_size)

# %% [markdown]
# ## Initialize CERerankingEvaluator Class
# ### The CERerankingEvaluator class evaluates the model after every 1k steps of training on the validation set
# ### Currently, CERerankingEvaluator computes MRR@10 on the valiadion set. You need to change MRR@10 to NDCG@10 for Exercise 4.
# ###For that, you can download the CERerankingEvaluator class ([link](https://github.com/UKPLab/sentence-transformers/blob/master/sentence_transformers/cross_encoder/evaluation/CERerankingEvaluator.py)) and upload the modified implementation to the brightspace.

# %%
# We add an evaluator, which evaluates the performance during training
# It performs a classification task and measures scores like F1 (finding relevant passages) and Average Precision
evaluator = CERerankingEvaluator(dev_samples, name='train-eval')

# %% [markdown]
# ## Train the model
# ### You can stop the training after one hour by stopping the run

# %%
# Train the model
model.fit(train_dataloader=train_dataloader,
          evaluator=evaluator,
          epochs=num_epochs,
          evaluation_steps=1000,
          warmup_steps=5000,
          output_path=model_save_path,
          use_amp=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:233: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/156250 [00:00<?, ?it/s]
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 1000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 65.27
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 71.80
# INFO:sentence_transformers.cross_encoder.CrossEncoder:Save model to ./gdrive/MyDrive/cross-encoder-reranker-ir-course-2023/finetuned_models/cross-encoder-cross-encoder-ms-marco-MiniLM-L-2-v2-2025-05-16_11-01-18
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 2000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 64.33
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 70.75
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 3000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.80
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.19
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 4000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 63.26
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.63
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 5000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 64.03
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 70.50
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 6000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 63.24
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.88
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 7000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 63.04
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.89
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 8000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.40
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.29
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 9000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 60.73
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 67.95
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 10000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 61.46
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 68.12
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 11000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 64.10
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 70.59
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 12000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.31
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.02
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 13000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.89
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 70.22
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 14000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.45
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.45
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 15000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.71
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.53
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 16000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 63.21
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.81
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 17000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.66
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.28
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 18000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.87
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.54
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 19000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 64.56
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 70.81
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 20000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 63.65
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 70.55
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 21000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 63.34
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.93
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 22000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.57
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.18
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 23000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 61.97
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 68.82
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 24000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.95
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.84
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 25000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.58
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.25
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 26000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.83
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.33
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 27000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 64.31
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 70.81
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 28000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 61.42
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 68.58
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 29000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.77
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.44
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 30000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 63.28
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.96
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 31000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.04
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 68.93
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 32000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 63.90
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 70.33
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 33000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.90
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.78
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 34000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 65.27
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 72.11
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 35000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.81
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.99
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 36000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.49
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.52
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 37000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 64.52
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 71.23
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 38000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 63.23
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.82
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 39000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 64.91
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 71.53
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 40000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.89
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.91
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 41000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.15
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.26
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 42000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 63.30
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 70.38
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 43000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.68
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.77
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 44000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.46
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.55
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 45000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 63.34
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 70.34
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 46000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.24
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.59
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 47000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 61.11
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 68.28
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 48000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 61.57
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 68.89
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 49000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.96
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.97
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 50000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 63.20
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 70.39
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 51000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 61.97
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.29
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 52000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 61.47
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 68.81
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 53000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.33
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.34
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 54000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.75
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.72
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 55000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.86
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.90
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 56000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 61.80
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 68.77
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 57000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 63.20
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 70.19
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 58000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 63.52
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 70.49
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 59000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 61.96
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.19
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 60000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 61.70
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 68.76
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 61000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 63.05
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 70.11
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 62000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 63.43
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 70.13
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 63000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 63.15
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 70.10
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 64000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 63.44
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 70.52
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 65000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 63.48
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 70.38
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 66000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.95
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.88
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 67000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.18
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.68
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 68000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 64.25
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 71.06
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 69000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.21
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.70
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 70000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 61.69
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 68.71
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 71000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.25
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.64
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 72000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 61.54
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 68.91
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 73000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 61.56
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 68.97
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 74000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 63.22
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 70.14
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 75000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 61.10
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 68.61
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 76000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 60.36
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 68.07
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 77000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 61.45
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 68.77
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 78000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 61.57
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.11
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 79000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 61.28
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.04
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 80000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 61.93
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.24
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 81000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 64.40
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 70.92
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 82000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 61.36
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 68.70
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 83000 steps:
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:Queries: 200 	 Positives: Min 1.0, Mean 1.1, Max 3.0 	 Negatives: Min 100.0, Mean 199.1, Max 200.0
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:MRR@10: 62.45
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:NDCG@10: 69.67
# INFO:sentence_transformers.cross_encoder.evaluation.CERerankingEvaluator:CERerankingEvaluator: Evaluating the model on train-eval dataset in epoch 0 after 84000 steps:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-9a3ab426eb07> in <cell line: 0>()
#       2
#       3 # Train the model
# ----> 4 model.fit(train_dataloader=train_dataloader,
#       5           evaluator=evaluator,
#       6           epochs=num_epochs,
#
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py in fit(self, train_dataloader, evaluator, epochs, loss_fct, activation_fct, scheduler, warmup_steps, optimizer_class, optimizer_params, weight_decay, evaluation_steps, output_path, save_best_model, max_grad_norm, use_amp, callback, show_progress_bar)
#     304
#     305                 if evaluator is not None and evaluation_steps > 0 and training_steps % evaluation_steps == 0:
# --> 306                     self._eval_during_training(
#     307                         evaluator, output_path, save_best_model, epoch, training_steps, callback
#     308                     )
#
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py in _eval_during_training(self, evaluator, output_path, save_best_model, epoch, steps, callback)
#     557         """Runs evaluation during the training"""
#     558         if evaluator is not None:
# --> 559             score = evaluator(self, output_path=output_path, epoch=epoch, steps=steps)
#     560             if callback is not None:
#     561                 callback(score, epoch, steps)
#
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/cross_encoder/evaluation/CERerankingEvaluator.py in __call__(self, model, output_path, epoch, steps)
#      76
#      77             model_input = [[query, doc] for doc in docs]
# ---> 78             pred_scores = model.predict(model_input, convert_to_numpy=True, show_progress_bar=False)
#      79             pred_scores_argsort = np.argsort(-pred_scores)  # Sort in decreasing order
#      80
#
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py in predict(self, sentences, batch_size, show_progress_bar, num_workers, activation_fct, apply_softmax, convert_to_numpy, convert_to_tensor)
#     438         self.model.eval()
#     439         with torch.no_grad():
# --> 440             for features in iterator:
#     441                 model_predictions = self.model(**features, return_dict=True)
#     442                 logits = activation_fct(model_predictions.logits)
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     706                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707                 self._reset()  # type: ignore[call-arg]
# --> 708             data = self._next_data()
#     709             self._num_yielded += 1
#     710             if (
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     762     def _next_data(self):
#     763         index = self._next_index()  # may raise StopIteration
# --> 764         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765         if self._pin_memory:
#     766             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
# ---> 55         return self.collate_fn(data)
#
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py in smart_batching_collate_text_only(self, batch)
#     174
#     175         for name in tokenized:
# --> 176             tokenized[name] = tokenized[name].to(self.model.device)
#     177
#     178         return tokenized
#
# KeyboardInterrupt:

# %%
import sentence_transformers
sentence_transformers.__version__
